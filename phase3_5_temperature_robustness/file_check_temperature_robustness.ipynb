# %%
import pandas as pd
import os
from pathlib import Path
import glob

# Auto-discovery of latest Phase 3.5 data
datasets_dir = "../data/phase3_5/"
pattern = os.path.join(datasets_dir, "dataset_temp_*.parquet")
matching_files = glob.glob(pattern)

if matching_files:
    # Sort by modification time, newest first
    matching_files.sort(key=lambda x: os.path.getmtime(x), reverse=True)
    print(f"🔍 Found {len(matching_files)} temperature files (newest first)")
    for file in matching_files:
        print(f"  📁 {Path(file).name}")
else:
    raise FileNotFoundError(f"No temperature dataset files found in {datasets_dir}")
# Out:
# 🔍 Found 5 temperature files (newest first)
#   📁 dataset_temp_0_6.parquet
#   📁 dataset_temp_1_2.parquet
#   📁 dataset_temp_0_9.parquet
#   📁 dataset_temp_0_3.parquet
#   📁 dataset_temp_0_0.parquet

# %%
# Load and display first 5 records for each temperature dataset
for file_path in matching_files:
    file_name = Path(file_path).name
    print(f"\n{'='*50}")
    print(f"Dataset: {file_name}")
    print(f"{'='*50}")
    
    df = pd.read_parquet(file_path)
    print(f"Records: {len(df)}")
    print(f"Columns: {list(df.columns)}")
    print("\nFirst 5 records:")
    display(df.head(50))
# Out:
# ==================================================
# Dataset: dataset_temp_0_6.parquet
# ==================================================
# Records: 60
# Columns: ['task_id', 'temperature', 'prompt', 'generated_code', 'test_passed', 'error_message', 'generation_time', 'cyclomatic_complexity', 'generation_idx']
#
# First 5 records:
#     task_id  temperature                                             prompt  \
# 0         1          0.6  Write a Python function to solve the following...
# 1         1          0.6  Write a Python function to solve the following...
# 2         1          0.6  Write a Python function to solve the following...
# 3         5          0.6  Write a Python function to solve the following...
# 4         5          0.6  Write a Python function to solve the following...
# 5         5          0.6  Write a Python function to solve the following...
# 6         8          0.6  Write a Python function to solve the following...
# 7         8          0.6  Write a Python function to solve the following...
# 8         8          0.6  Write a Python function to solve the following...
# 9        10          0.6  Write a Python function to solve the following...
# 10       10          0.6  Write a Python function to solve the following...
# 11       10          0.6  Write a Python function to solve the following...
# 12       14          0.6  Write a Python function to solve the following...
# 13       14          0.6  Write a Python function to solve the following...
# 14       14          0.6  Write a Python function to solve the following...
# 15       17          0.6  Write a Python function to solve the following...
# 16       17          0.6  Write a Python function to solve the following...
# 17       17          0.6  Write a Python function to solve the following...
# 18       18          0.6  Write a Python function to solve the following...
# 19       18          0.6  Write a Python function to solve the following...
# 20       18          0.6  Write a Python function to solve the following...
# 21       20          0.6  Write a Python function to solve the following...
# 22       20          0.6  Write a Python function to solve the following...
# 23       20          0.6  Write a Python function to solve the following...
# 24       21          0.6  Write a Python function to solve the following...
# 25       21          0.6  Write a Python function to solve the following...
# 26       21          0.6  Write a Python function to solve the following...
# 27       22          0.6  Write a Python function to solve the following...
# 28       22          0.6  Write a Python function to solve the following...
# 29       22          0.6  Write a Python function to solve the following...
# 30       24          0.6  Write a Python function to solve the following...
# 31       24          0.6  Write a Python function to solve the following...
# 32       24          0.6  Write a Python function to solve the following...
# 33       27          0.6  Write a Python function to solve the following...
# 34       27          0.6  Write a Python function to solve the following...
# 35       27          0.6  Write a Python function to solve the following...
# 36       29          0.6  Write a Python function to solve the following...
# 37       29          0.6  Write a Python function to solve the following...
# 38       29          0.6  Write a Python function to solve the following...
# 39       37          0.6  Write a Python function to solve the following...
# 40       37          0.6  Write a Python function to solve the following...
# 41       37          0.6  Write a Python function to solve the following...
# 42       40          0.6  Write a Python function to solve the following...
# 43       40          0.6  Write a Python function to solve the following...
# 44       40          0.6  Write a Python function to solve the following...
# 45       43          0.6  Write a Python function to solve the following...
# 46       43          0.6  Write a Python function to solve the following...
# 47       43          0.6  Write a Python function to solve the following...
# 48       47          0.6  Write a Python function to solve the following...
# 49       47          0.6  Write a Python function to solve the following...
#
#                                        generated_code  test_passed  \
# 0   def min_cost(cost, m, n):\n    # Your code her...        False
# 1   def min_cost(cost, m, n):\n\n# Your code here\...        False
# 2   def min_cost(cost, m, n):\n    # Write your co...        False
# 3   # Solution:\ndef count_ways(n):\n    if n == 1...        False
# 4   def count_ways(n):\n    return 0\n\n# Test cod...        False
# 5   # Function definition\ndef count_ways(n):\n   ...        False
# 6                              def square_nums(nums):        False
# 7   def square_nums(nums):\n    return [lambda x: ...        False
# 8   def square_nums(nums):\n    return [x**2 for x...         True
# 9   def small_nnum(dataSet,n):\n    """\n    This ...        False
# 10         def small_nnum(num,n):\n    return num[:n]        False
# 11             def small_nnum(dataset,n):\n    return        False
# 12            def find_Volume(a,b,c):\n...\nreturn...        False
# 13  def find_Volume(base_length, base_width, heigh...        False
# 14  def find_Volume(base, height, depth):\n    ret...        False
# 15         def square_perimeter(n):\n    return n * 4         True
# 16  def square_perimeter(size):\n    """Return the...        False
# 17               def square_perimeter(x):\nreturn x*4        False
# 18  def remove_dirty_chars(first_string, second_st...        False
# 19  def remove_dirty_chars(first_string, second_st...        False
# 20  def remove_dirty_chars(first, second):\n   return        False
# 21  def is_woodball(n):\n\t# your code here\n\treturn        False
# 22  def is_woodball(number):\n    # Your code here...        False
# 23  def is_woodall(number):\n    if number % 2 == ...        False
# 24  def multiples_of_num(n, m):\n    return []\n\n...        False
# 25  def multiples_of_num(number,num):\n    for i i...        False
# 26  def multiples_of_num(num, n):\n    """\n    :p...        False
# 27  def find_first_duplicate(arr):\n    for i in r...        False
# 28  def find_first_duplicate(arr):\n    # Your cod...        False
# 29  # function to find the first duplicate element...         True
# 30  # This function is used to convert a binary nu...        False
# 31  def binary_to_decimal(binary_number):\n\n# Wri...        False
# 32  def binary_to_decimal(binary):\n    """\n    >...        False
# 33  def remove(lst):\n    lst = [word for word in ...        False
# 34  def remove(ls):\n    for i in range(len(ls)):\...        False
# 35  def remove(string_list):\n   return [string.re...        False
# 36  def get_Odd_Occurrence(A,k):\n    count=0\n   ...        False
# 37  def get_Odd_Occurrence(arr, n):\n    """\n    ...        False
# 38  def get_Odd_Occurrence(arr, n):\n    for i in ...         True
# 39  def sort_mixed_list(mixed_list):\n    # TODO: ...        False
# 40                   def sort_mixed_list(mixed_list):        False
# 41          def sort_mixed_list(list_):\nreturn list_        False
# 42  # Returns a dictionary containing the frequenc...        False
# 43  def freq_element(lst):\n    """\n    Return li...        False
# 44  def freq_element(lst):\n    """\n    Takes a l...        False
# 45  def text_match(text):\n    if text.find("ab_")...        False
# 46  def text_match(text): \n    pass\n\n\n# Test c...        False
# 47  def text_match(text):\n  return "Found a match...        False
# 48  def compute_Last_Digit(n,m):\n    \n    return...        False
# 49  def compute_Last_Digit(n,m):\nif n%m == 0:\nre...        False
#
#    error_message  generation_time  cyclomatic_complexity  generation_idx
# 0           None        29.381733                      7               0
# 1           None        11.851039                      7               1
# 2           None        33.136135                      7               2
# 3           None        22.800214                      2               0
# 4           None         9.309174                      2               1
# 5           None        12.254187                      2               2
# 6           None         1.986590                      1               0
# 7           None         4.100458                      1               1
# 8           None         3.648428                      1               2
# 9           None        22.197321                      1               0
# 10          None         3.450862                      1               1
# 11          None         2.830670                      1               2
# 12          None         3.520698                      1               0
# 13          None         6.116360                      1               1
# 14          None         3.471430                      1               2
# 15          None         3.387894                      1               0
# 16          None        10.756561                      1               1
# 17          None         2.491874                      1               2
# 18          None        10.711066                      3               0
# 19          None       433.297084                      3               1
# 20          None         2.933351                      3               2
# 21          None         4.570941                      5               0
# 22          None        11.766478                      5               1
# 23          None         7.566407                      5               2
# 24          None        20.091348                      1               0
# 25          None        13.909709                      1               1
# 26          None        12.268049                      1               2
# 27          None        33.022684                      3               0
# 28          None         3.616200                      3               1
# 29          None        14.738950                      3               2
# 30          None        47.113394                      2               0
# 31          None         3.814425                      2               1
# 32          None        14.831622                      2               2
# 33          None        30.652012                      2               0
# 34          None        19.338729                      2               1
# 35          None        35.336057                      2               2
# 36          None        12.631039                      5               0
# 37          None        10.284239                      5               1
# 38          None         8.399311                      5               2
# 39          None         5.187799                      5               0
# 40          None         2.700452                      5               1
# 41          None         3.026157                      5               2
# 42          None        11.937063                      1               0
# 43          None         8.645167                      1               1
# 44          None       111.916907                      1               2
# 45          None        14.789986                      2               0
# 46          None        11.142926                      2               1
# 47          None         5.598256                      2               2
# 48          None         8.504455                      4               0
# 49          None         5.480169                      4               1
# ==================================================
# Dataset: dataset_temp_1_2.parquet
# ==================================================
# Records: 50
# Columns: ['task_id', 'temperature', 'prompt', 'generated_code', 'test_passed', 'error_message', 'generation_time', 'cyclomatic_complexity', 'generation_idx']
#
# First 5 records:
#     task_id  temperature                                             prompt  \
# 0         1          1.2  Write a Python function to solve the following...
# 1         1          1.2  Write a Python function to solve the following...
# 2         1          1.2  Write a Python function to solve the following...
# 3         1          1.2  Write a Python function to solve the following...
# 4         1          1.2  Write a Python function to solve the following...
# 5         5          1.2  Write a Python function to solve the following...
# 6         5          1.2  Write a Python function to solve the following...
# 7         5          1.2  Write a Python function to solve the following...
# 8         5          1.2  Write a Python function to solve the following...
# 9         5          1.2  Write a Python function to solve the following...
# 10        8          1.2  Write a Python function to solve the following...
# 11        8          1.2  Write a Python function to solve the following...
# 12        8          1.2  Write a Python function to solve the following...
# 13        8          1.2  Write a Python function to solve the following...
# 14        8          1.2  Write a Python function to solve the following...
# 15       10          1.2  Write a Python function to solve the following...
# 16       10          1.2  Write a Python function to solve the following...
# 17       10          1.2  Write a Python function to solve the following...
# 18       10          1.2  Write a Python function to solve the following...
# 19       10          1.2  Write a Python function to solve the following...
# 20       14          1.2  Write a Python function to solve the following...
# 21       14          1.2  Write a Python function to solve the following...
# 22       14          1.2  Write a Python function to solve the following...
# 23       14          1.2  Write a Python function to solve the following...
# 24       14          1.2  Write a Python function to solve the following...
# 25       17          1.2  Write a Python function to solve the following...
# 26       17          1.2  Write a Python function to solve the following...
# 27       17          1.2  Write a Python function to solve the following...
# 28       17          1.2  Write a Python function to solve the following...
# 29       17          1.2  Write a Python function to solve the following...
# 30       18          1.2  Write a Python function to solve the following...
# 31       18          1.2  Write a Python function to solve the following...
# 32       18          1.2  Write a Python function to solve the following...
# 33       18          1.2  Write a Python function to solve the following...
# 34       18          1.2  Write a Python function to solve the following...
# 35       20          1.2  Write a Python function to solve the following...
# 36       20          1.2  Write a Python function to solve the following...
# 37       20          1.2  Write a Python function to solve the following...
# 38       20          1.2  Write a Python function to solve the following...
# 39       20          1.2  Write a Python function to solve the following...
# 40       21          1.2  Write a Python function to solve the following...
# 41       21          1.2  Write a Python function to solve the following...
# 42       21          1.2  Write a Python function to solve the following...
# 43       21          1.2  Write a Python function to solve the following...
# 44       21          1.2  Write a Python function to solve the following...
# 45       22          1.2  Write a Python function to solve the following...
# 46       22          1.2  Write a Python function to solve the following...
# 47       22          1.2  Write a Python function to solve the following...
# 48       22          1.2  Write a Python function to solve the following...
# 49       22          1.2  Write a Python function to solve the following...
#
#                                        generated_code  test_passed  \
# 0   import functools\n\ndef min(x):\n    functools...        False
# 1   '''This code will calculate the path from the ...        False
# 2   def min_cost(cost, destination, n):\n\nIf you ...        False
# 3   function code for min_cost()\nimport numpy as ...        False
# 4   def min_cost(cost, m, n):\n    for i in range(...        False
# 5   import unittest\n\ndef count_ways(rows, cols) ...        False
# 6   Note:\nDon't reinvent the solution for DP!\n\n...        False
# 7                                  def count_ways(n):        False
# 8                                                            False
# 9   def count_ways(n):\n# base case\nif n >= 1:\n#...        False
# 10  square_nums = lambda L: [x**2 for x in L ]\nTe...        False
# 11  square_nums = lambda my_list: [\n    f"({my_li...        False
# 12  def square_nums(inList):\n  if len(inList) == ...        False
# 13  # square the given args tuple\nsquareNum = lam...        False
# 14  def square_nums(num_list):\n  # YOUR ANSWER HE...        False
# 15                               def small_n(data,n):        False
# 16  small_n(dataset, n)\n    if n>len(dataset)\n  ...        False
# 17  def small_n(array, n):\nans = []\nindex = rang...        False
# 18           Hint: use sorted, and some sort of loop.        False
# 19  def small_n num ,n: [ int,list ]\nfor val in n...        False
# 20               def find_Volume(a,b,c):\n     return        False
# 21                                                           False
# 22  def Find_Volume (bottom_Ledge, side_length, he...        False
# 23  import mathdef find_Volume(baseLength, baseWid...        False
# 24  def find_Volume(a=1, b=1,h=1):\n    """Input: ...        False
# 25  def square_perimeter(side_length):\n return si...        False
# 26  square_perimeter = def n(n)\n\nsquare_perimete...        False
# 27  Answer1:\n\n\ndef square_perimeter(A):\n\n\tre...        False
# 28  # def square_perimeter(length: float):\n#     ...        False
# 29  function(int perimeterLength:\nif perimeterLen...        False
# 30  def remove_dirty_chars(dirty_chars, clean_stri...        False
# 31                                                           False
# 32  def remove_dirty_chars(s1, s2):\n    s1=s1[:i]...        False
# 33                                      Solution code        False
# 34  def checkListCount(checkValues, value, lstInde...        False
# 35  is_woodall = 0 \n\n\ndef  (param):\n\n# Your c...        False
# 36        # def my_function(a)\n# Your solution here:        False
# 37  def is_Woodall(n):\n  n = list(map(int,str(n))...        False
# 38  def is_woodall_for(x):\nreturn x % 10 == 5 and...        False
# 39                                 def is_woodball(i)        False
# 40  def multiples_of_num(num, n):\n\n# Write ONLY ...        False
# 41  # def multiples_of_num( num, factor ): # Write...        False
# 42                                                           False
# 43  def multiples_of_num(num,limit):\n    list = [...        False
# 44          def multiples_of_num(num,limit):\n   pass        False
# 45           def find_first_duplicate(s):\n# return 1        False
# 46  def find_first_duplicate(array):\n    if array...        False
# 47  if myList != range(len(myList)):\n    for i in...        False
# 48  def find_first_duplicate(numberslist):\n"""\nR...        False
# 49  def find_first_duplicate(arr):\nlist_result =[...        False
#
#    error_message  generation_time  cyclomatic_complexity  generation_idx
# 0           None        25.437566                      7               0
# 1           None        46.358381                      7               1
# 2           None        41.394968                      7               2
# 3           None        44.331651                      7               3
# 4           None        18.396529                      7               4
# 5           None         6.213836                      2               0
# 6           None       101.822943                      2               1
# 7           None         2.016571                      2               2
# 8           None         0.320443                      2               3
# 9           None        20.159765                      2               4
# 10          None        20.559650                      1               0
# 11          None        30.681398                      1               1
# 12          None        27.456866                      1               2
# 13          None        15.526094                      1               3
# 14          None        39.796810                      1               4
# 15          None         2.527617                      1               0
# 16          None         3.919725                      1               1
# 17          None         9.039749                      1               2
# 18          None         2.523874                      1               3
# 19          None         5.216310                      1               4
# 20          None         3.436583                      1               0
# 21          None         0.526253                      1               1
# 22          None        13.600959                      1               2
# 23          None        41.196001                      1               3
# 24          None        18.577864                      1               4
# 25          None         7.249880                      1               0
# 26          None       103.149857                      1               1
# 27          None         9.271019                      1               2
# 28          None        26.064078                      1               3
# 29          None        11.436843                      1               4
# 30          None         3.213924                      3               0
# 31          None         0.336276                      3               1
# 32          None         5.289234                      3               2
# 33          None         0.785794                      3               3
# 34          None        23.363648                      3               4
# 35          None         4.025621                      5               0
# 36          None         2.830136                      5               1
# 37          None        44.879717                      5               2
# 38          None         6.694160                      5               3
# 39          None         1.911728                      5               4
# 40          None         3.895241                      1               0
# 41          None        18.141215                      1               1
# 42          None         0.388265                      1               2
# 43          None        50.980278                      1               3
# 44          None         2.862165                      1               4
# 45          None         2.812677                      3               0
# 46          None        23.235740                      3               1
# 47          None        26.944088                      3               2
# 48          None        20.465377                      3               3
# 49          None         4.101178                      3               4
# ==================================================
# Dataset: dataset_temp_0_9.parquet
# ==================================================
# Records: 50
# Columns: ['task_id', 'temperature', 'prompt', 'generated_code', 'test_passed', 'error_message', 'generation_time', 'cyclomatic_complexity', 'generation_idx']
#
# First 5 records:
#     task_id  temperature                                             prompt  \
# 0         1          0.9  Write a Python function to solve the following...
# 1         1          0.9  Write a Python function to solve the following...
# 2         1          0.9  Write a Python function to solve the following...
# 3         1          0.9  Write a Python function to solve the following...
# 4         1          0.9  Write a Python function to solve the following...
# 5         5          0.9  Write a Python function to solve the following...
# 6         5          0.9  Write a Python function to solve the following...
# 7         5          0.9  Write a Python function to solve the following...
# 8         5          0.9  Write a Python function to solve the following...
# 9         5          0.9  Write a Python function to solve the following...
# 10        8          0.9  Write a Python function to solve the following...
# 11        8          0.9  Write a Python function to solve the following...
# 12        8          0.9  Write a Python function to solve the following...
# 13        8          0.9  Write a Python function to solve the following...
# 14        8          0.9  Write a Python function to solve the following...
# 15       10          0.9  Write a Python function to solve the following...
# 16       10          0.9  Write a Python function to solve the following...
# 17       10          0.9  Write a Python function to solve the following...
# 18       10          0.9  Write a Python function to solve the following...
# 19       10          0.9  Write a Python function to solve the following...
# 20       14          0.9  Write a Python function to solve the following...
# 21       14          0.9  Write a Python function to solve the following...
# 22       14          0.9  Write a Python function to solve the following...
# 23       14          0.9  Write a Python function to solve the following...
# 24       14          0.9  Write a Python function to solve the following...
# 25       17          0.9  Write a Python function to solve the following...
# 26       17          0.9  Write a Python function to solve the following...
# 27       17          0.9  Write a Python function to solve the following...
# 28       17          0.9  Write a Python function to solve the following...
# 29       17          0.9  Write a Python function to solve the following...
# 30       18          0.9  Write a Python function to solve the following...
# 31       18          0.9  Write a Python function to solve the following...
# 32       18          0.9  Write a Python function to solve the following...
# 33       18          0.9  Write a Python function to solve the following...
# 34       18          0.9  Write a Python function to solve the following...
# 35       20          0.9  Write a Python function to solve the following...
# 36       20          0.9  Write a Python function to solve the following...
# 37       20          0.9  Write a Python function to solve the following...
# 38       20          0.9  Write a Python function to solve the following...
# 39       20          0.9  Write a Python function to solve the following...
# 40       21          0.9  Write a Python function to solve the following...
# 41       21          0.9  Write a Python function to solve the following...
# 42       21          0.9  Write a Python function to solve the following...
# 43       21          0.9  Write a Python function to solve the following...
# 44       21          0.9  Write a Python function to solve the following...
# 45       22          0.9  Write a Python function to solve the following...
# 46       22          0.9  Write a Python function to solve the following...
# 47       22          0.9  Write a Python function to solve the following...
# 48       22          0.9  Write a Python function to solve the following...
# 49       22          0.9  Write a Python function to solve the following...
#
#                                        generated_code  test_passed  \
# 0   def min_cost(costs, m, n):\n   # Function to f...        False
# 1   min_cost(cost_matrix, m, n):\n    # Check if t...        False
# 2   def min_cost(cost, m, n):\n    m, n = 10, 4\n ...        False
# 3   def min_cost(cost, m, n):\n    if m < 0 or m >...        False
# 4   def min_cost(cost, m, n):\n    # Calculate num...        False
# 5   def count_ways(n):\n    return\n\n# Return the...        False
# 6   def count_ways(length):\nreturn 0\n\n# Test th...        False
# 7                                                            False
# 8   from math import factorial\ndef count_ways(n):...        False
# 9   class Solution:\n    """\n    @param dominoes:...        False
# 10                             def square_nums(nums):        False
# 11  def square_nums(nums):\n    """Squares all the...         True
# 12  def square_nums(my_list):\n    return [x**2 fo...         True
# 13  # testcode: if __name__=="__main__":\n#     as...         True
# 14  def square_nums(number_list):\n# Write your co...        False
# 15                                                           False
# 16  def small_nnum(arr, n):\n    # Your code here:...        False
# 17  def small_nnum(lista, n):\n  if n<1:\n    retu...        False
# 18  def small_nnum (mylist,n):\nif n > len(mylist)...        False
# 19  def small_nnum(list_in, num_elements):\n    # ...        False
# 20  def findVolume(width, height, base):\n# Add yo...        False
# 21  import pytest\n\ndef find_Volume(a,b,c):\n    ...        False
# 22  def find_Volume(height,sideA,sideB):\n    retu...        False
# 23  #\ndef find_Volume(height, base_l, base_w):\n(...        False
# 24  def find_Volume (side1, side2, side3):\n    re...        False
# 25  def square_perimeter(side_length):\n    return...        False
# 26  def square_perimeter(side_length: int):\n     ...         True
# 27  <code>def square_perimeter(length):</code>\n\n...        False
# 28  def square_perimeter(x):\n    #TODO: write you...        False
# 29  def square_perimeter(a):\n    perimeter = 4 * ...         True
# 30  def remove_dirty_chars(dirty_chars, clean_char...        False
# 31  def remove_dirty_chars(stringA, stringB):\nfor...        False
# 32      # def remove_dirty_chars(string, characters):        False
# 33  # Python function definition\ndef function_nam...        False
# 34  def remove_dirty_chars(string1, string2):    \...        False
# 35  def is_woodall(number):\nif number % 2 == 0:\n...        False
# 36  def is_woodall(n):\n  if n > 253:\n    return ...        False
# 37  def is_woodall(n):\n"""Is n a perfect square w...        False
# 38  def is_woodall(number):\nfor numbers in number...        False
# 39  def is_woodall(number):\nif number % 10 == 0 a...        False
# 40  def multiples_of_num(a,b):\n# Your code here\n...        False
# 41  def multiples_of_num(n, m):\n    for i in rang...        False
# 42  def multiples_of_num(num1, num2):\n    outlist...        False
# 43  def multiples_of_num(n, m):\n   while m>0:\n  ...        False
# 44  def multiples_of_num(n,m):\n    return [i for ...        False
# 45  # Input:\n# print(find_first_duplicate([1, 2, ...        False
# 46  def find_first_duplicate(lst):\n    for i in r...         True
# 47  def find_first_duplicate(input_list):\n    """...        False
# 48  def find_first_duplicate(arr: list):\n\n    if...        False
# 49  def find_first_duplicate(A) :\n    for i in ra...        False
#
#    error_message  generation_time  cyclomatic_complexity  generation_idx
# 0           None       409.007721                      7               0
# 1           None        15.275557                      7               1
# 2           None       315.441344                      7               2
# 3           None        28.833237                      7               3
# 4           None       200.918921                      7               4
# 5           None         5.949788                      2               0
# 6           None         9.234527                      2               1
# 7           None         0.324869                      2               2
# 8           None       192.334744                      2               3
# 9           None        96.731005                      2               4
# 10          None         1.830378                      1               0
# 11          None         5.433254                      1               1
# 12          None         4.358345                      1               2
# 13          None        29.922984                      1               3
# 14          None         3.589472                      1               4
# 15          None         0.689563                      1               0
# 16          None        25.322050                      1               1
# 17          None        88.366502                      1               2
# 18          None        25.506492                      1               3
# 19          None         3.751682                      1               4
# 20          None         3.170657                      1               0
# 21          None        24.085640                      1               1
# 22          None         5.342473                      1               2
# 23          None         5.208727                      1               3
# 24          None         5.119191                      1               4
# 25          None        49.627681                      1               0
# 26          None         3.721979                      1               1
# 27          None        11.838696                      1               2
# 28          None         2.811269                      1               3
# 29          None         4.056693                      1               4
# 30          None        14.529734                      3               0
# 31          None        34.858632                      3               1
# 32          None         2.496535                      3               2
# 33          None        16.371241                      3               3
# 34          None        77.722971                      3               4
# 35          None         8.663411                      5               0
# 36          None         9.839661                      5               1
# 37          None         3.757072                      5               2
# 38          None         5.311363                      5               3
# 39          None        19.312207                      5               4
# 40          None        20.500495                      1               0
# 41          None      3679.263284                      1               1
# 42          None        24.058349                      1               2
# 43          None         8.676469                      1               3
# 44          None        11.255139                      1               4
# 45          None        20.217266                      3               0
# 46          None        25.314212                      3               1
# 47          None        17.623936                      3               2
# 48          None        33.658044                      3               3
# 49          None        50.733168                      3               4
# ==================================================
# Dataset: dataset_temp_0_3.parquet
# ==================================================
# Records: 50
# Columns: ['task_id', 'temperature', 'prompt', 'generated_code', 'test_passed', 'error_message', 'generation_time', 'cyclomatic_complexity', 'generation_idx']
#
# First 5 records:
#     task_id  temperature                                             prompt  \
# 0         1          0.3  Write a Python function to solve the following...
# 1         1          0.3  Write a Python function to solve the following...
# 2         1          0.3  Write a Python function to solve the following...
# 3         1          0.3  Write a Python function to solve the following...
# 4         1          0.3  Write a Python function to solve the following...
# 5         5          0.3  Write a Python function to solve the following...
# 6         5          0.3  Write a Python function to solve the following...
# 7         5          0.3  Write a Python function to solve the following...
# 8         5          0.3  Write a Python function to solve the following...
# 9         5          0.3  Write a Python function to solve the following...
# 10        8          0.3  Write a Python function to solve the following...
# 11        8          0.3  Write a Python function to solve the following...
# 12        8          0.3  Write a Python function to solve the following...
# 13        8          0.3  Write a Python function to solve the following...
# 14        8          0.3  Write a Python function to solve the following...
# 15       10          0.3  Write a Python function to solve the following...
# 16       10          0.3  Write a Python function to solve the following...
# 17       10          0.3  Write a Python function to solve the following...
# 18       10          0.3  Write a Python function to solve the following...
# 19       10          0.3  Write a Python function to solve the following...
# 20       14          0.3  Write a Python function to solve the following...
# 21       14          0.3  Write a Python function to solve the following...
# 22       14          0.3  Write a Python function to solve the following...
# 23       14          0.3  Write a Python function to solve the following...
# 24       14          0.3  Write a Python function to solve the following...
# 25       17          0.3  Write a Python function to solve the following...
# 26       17          0.3  Write a Python function to solve the following...
# 27       17          0.3  Write a Python function to solve the following...
# 28       17          0.3  Write a Python function to solve the following...
# 29       17          0.3  Write a Python function to solve the following...
# 30       18          0.3  Write a Python function to solve the following...
# 31       18          0.3  Write a Python function to solve the following...
# 32       18          0.3  Write a Python function to solve the following...
# 33       18          0.3  Write a Python function to solve the following...
# 34       18          0.3  Write a Python function to solve the following...
# 35       20          0.3  Write a Python function to solve the following...
# 36       20          0.3  Write a Python function to solve the following...
# 37       20          0.3  Write a Python function to solve the following...
# 38       20          0.3  Write a Python function to solve the following...
# 39       20          0.3  Write a Python function to solve the following...
# 40       21          0.3  Write a Python function to solve the following...
# 41       21          0.3  Write a Python function to solve the following...
# 42       21          0.3  Write a Python function to solve the following...
# 43       21          0.3  Write a Python function to solve the following...
# 44       21          0.3  Write a Python function to solve the following...
# 45       22          0.3  Write a Python function to solve the following...
# 46       22          0.3  Write a Python function to solve the following...
# 47       22          0.3  Write a Python function to solve the following...
# 48       22          0.3  Write a Python function to solve the following...
# 49       22          0.3  Write a Python function to solve the following...
#
#                                        generated_code  test_passed  \
# 0   def min_cost(cost, m, n):\n    # Your code her...        False
# 1   def min_cost(cost, m, n):\n    # Your code her...        False
# 2   def min_cost(cost, m, n):\n    # Write your co...        False
# 3   def min_cost(cost, m, n):\n    # Write your co...        False
# 4   def min_cost(cost, m, n):\n    # Your code her...        False
# 5   def count_ways(n):\n    if n == 1:\n        re...        False
# 6   def count_ways(n):\n\n# Your code here:\nretur...        False
# 7   def count_ways(n):\n    if n == 1:\n        re...        False
# 8   def count_ways(n):\n    return 0\n\n# Test cod...        False
# 9   def count_ways(n):\n    # Your code here:\n   ...        False
# 10  def square_nums(nums):\n    return [x**2 for x...        False
# 11  def square_nums(nums):\n    return [x**2 for x...         True
# 12  def square_nums(nums):\n    return [x**2 for x...         True
# 13  def square_nums(nums):\n    return [x**2 for x...         True
# 14  def square_nums(nums):\n    return [x**2 for x...         True
# 15  def small_nnum(num_list, n):\n    # your code ...        False
# 16  def small_nnum(nums,n):\n    return nums[:n]\n...        False
# 17  def small_nnum(arr,n):\n    arr.sort()\n    re...         True
# 18  def small_nnum(data, n):\n    # Your code here...        False
# 19  def small_nnum(num_list, n):\n    # Write your...        False
# 20  def find_Volume(base_length, height, width):\n...        False
# 21  def find_Volume(base, height, depth):\n    vol...        False
# 22  def find_Volume(height, width, depth):\n    re...        False
# 23  def find_Volume(base, height, length):\n    re...        False
# 24  def find_Volume(base, height, width):\n    ret...        False
# 25   def square_perimeter(side):\n    return side * 4         True
# 26  def square_perimeter(side_length):\n    return...        False
# 27   def square_perimeter(side):\n    return side * 4         True
# 28    def square_perimeter(side):\n    return side**2        False
# 29    def square_perimeter(side):\n    return side**2        False
# 30  def remove_dirty_chars(s1, s2):\n    for i in ...         True
# 31  def remove_dirty_chars(string1, string2):\n   ...        False
# 32  def remove_dirty_chars(dirty_string, clean_str...        False
# 33  def remove_dirty_chars(s1, s2):\n    return s1...        False
# 34  def remove_dirty_chars(string1, string2):\n   ...         True
# 35  def is_woodall(n):\n    if n % 2 == 0:\n      ...         True
# 36  def is_woodall(number):\n    if number % 2 == ...        False
# 37  def is_woodall(number):\n    if number % 10 ==...        False
# 38  def is_woodall(n):\n    # Write your code here...        False
# 39  def is_woodall(n):\n    if n < 100:\n        r...        False
# 40  def multiples_of_num(num, m):\n    return [num...        False
# 41  def multiples_of_num(num, n):\n    return [x f...        False
# 42  def multiples_of_num(num, m):\n    return [i f...        False
# 43  def multiples_of_num(num,n):\nreturn [num*i fo...        False
# 44  def multiples_of_num(num, m):\n    """\n    :t...        False
# 45  def find_first_duplicate(arr):\n    for i in r...         True
# 46  def find_first_duplicate(array):\n    for i in...         True
# 47  def find_first_duplicate(arr):\n    # Write yo...         True
# 48  def find_first_duplicate(arr):\n    for i in r...         True
# 49  def find_first_duplicate(arr):\n    for i in r...         True
#
#    error_message  generation_time  cyclomatic_complexity  generation_idx
# 0           None        30.142816                      7               0
# 1           None         4.318848                      7               1
# 2           None        24.402323                      7               2
# 3           None        24.097416                      7               3
# 4           None         4.014662                      7               4
# 5           None       412.710801                      2               0
# 6           None         3.885333                      2               1
# 7           None        12.791249                      2               2
# 8           None         9.233836                      2               3
# 9           None         3.250301                      2               4
# 10          None        25.160510                      1               0
# 11          None         3.664215                      1               1
# 12          None         3.685547                      1               2
# 13          None         3.691754                      1               3
# 14          None         3.638409                      1               4
# 15          None         5.224160                      1               0
# 16          None        33.816346                      1               1
# 17          None         4.354375                      1               2
# 18          None         3.905835                      1               3
# 19          None        34.819372                      1               4
# 20          None        12.816495                      1               0
# 21          None         4.362321                      1               1
# 22          None        11.788416                      1               2
# 23          None         3.596721                      1               3
# 24          None         3.440847                      1               4
# 25          None         5.698055                      1               0
# 26          None         3.334361                      1               1
# 27          None         2.626872                      1               2
# 28          None         2.475791                      1               3
# 29          None         2.481782                      1               4
# 30          None         7.563076                      3               0
# 31          None        12.367804                      3               1
# 32          None         3.559368                      3               2
# 33          None        14.523278                      3               3
# 34          None        11.583221                      3               4
# 35          None        10.980401                      5               0
# 36          None        18.330283                      5               1
# 37          None         5.646274                      5               2
# 38          None         3.637805                      5               3
# 39          None         5.350657                      5               4
# 40          None        18.727973                      1               0
# 41          None         5.520704                      1               1
# 42          None         5.504842                      1               2
# 43          None         5.014522                      1               3
# 44          None         8.571895                      1               4
# 45          None        10.557724                      3               0
# 46          None        22.641066                      3               1
# 47          None        26.698022                      3               2
# 48          None         9.862262                      3               3
# 49          None         9.968363                      3               4
# ==================================================
# Dataset: dataset_temp_0_0.parquet
# ==================================================
# Records: 50
# Columns: ['task_id', 'temperature', 'prompt', 'generated_code', 'test_passed', 'error_message', 'generation_time', 'cyclomatic_complexity', 'generation_idx']
#
# First 5 records:
#     task_id  temperature                                             prompt  \
# 0         1          0.0  Write a Python function to solve the following...
# 1         5          0.0  Write a Python function to solve the following...
# 2         8          0.0  Write a Python function to solve the following...
# 3        10          0.0  Write a Python function to solve the following...
# 4        14          0.0  Write a Python function to solve the following...
# 5        17          0.0  Write a Python function to solve the following...
# 6        18          0.0  Write a Python function to solve the following...
# 7        20          0.0  Write a Python function to solve the following...
# 8        21          0.0  Write a Python function to solve the following...
# 9        22          0.0  Write a Python function to solve the following...
# 10       24          0.0  Write a Python function to solve the following...
# 11       27          0.0  Write a Python function to solve the following...
# 12       29          0.0  Write a Python function to solve the following...
# 13       37          0.0  Write a Python function to solve the following...
# 14       40          0.0  Write a Python function to solve the following...
# 15       43          0.0  Write a Python function to solve the following...
# 16       47          0.0  Write a Python function to solve the following...
# 17       50          0.0  Write a Python function to solve the following...
# 18       51          0.0  Write a Python function to solve the following...
# 19       52          0.0  Write a Python function to solve the following...
# 20       55          0.0  Write a Python function to solve the following...
# 21       57          0.0  Write a Python function to solve the following...
# 22       58          0.0  Write a Python function to solve the following...
# 23       59          0.0  Write a Python function to solve the following...
# 24       61          0.0  Write a Python function to solve the following...
# 25       72          0.0  Write a Python function to solve the following...
# 26       74          0.0  Write a Python function to solve the following...
# 27       80          0.0  Write a Python function to solve the following...
# 28       82          0.0  Write a Python function to solve the following...
# 29       83          0.0  Write a Python function to solve the following...
# 30       84          0.0  Write a Python function to solve the following...
# 31       86          0.0  Write a Python function to solve the following...
# 32       89          0.0  Write a Python function to solve the following...
# 33       91          0.0  Write a Python function to solve the following...
# 34       92          0.0  Write a Python function to solve the following...
# 35       93          0.0  Write a Python function to solve the following...
# 36       94          0.0  Write a Python function to solve the following...
# 37       95          0.0  Write a Python function to solve the following...
# 38       99          0.0  Write a Python function to solve the following...
# 39      100          0.0  Write a Python function to solve the following...
# 40      105          0.0  Write a Python function to solve the following...
# 41      109          0.0  Write a Python function to solve the following...
# 42      111          0.0  Write a Python function to solve the following...
# 43      113          0.0  Write a Python function to solve the following...
# 44      114          0.0  Write a Python function to solve the following...
# 45      115          0.0  Write a Python function to solve the following...
# 46      119          0.0  Write a Python function to solve the following...
# 47      122          0.0  Write a Python function to solve the following...
# 48      123          0.0  Write a Python function to solve the following...
# 49      130          0.0  Write a Python function to solve the following...
#
#                                        generated_code  test_passed  \
# 0   def min_cost(cost, m, n):\n    # Write your co...        False
# 1   def count_ways(n):\n    if n == 1:\n        re...        False
# 2   def square_nums(nums):\n    return [x**2 for x...         True
# 3   def small_nnum(num_list, n):\n    # Your code ...        False
# 4   def find_Volume(base, height, width):\n    ret...        False
# 5     def square_perimeter(side):\n    return side**2        False
# 6   def remove_dirty_chars(s1, s2):\n    return s1...        False
# 7   def is_woodall(number):\n    if number % 2 == ...        False
# 8   def multiples_of_num(num, n):\n    return [i f...        False
# 9   def find_first_duplicate(arr):\n    for i in r...         True
# 10  def binary_to_decimal(binary_number):\n    ret...        False
# 11                 def remove(list):\n    return list        False
# 12  def get_Odd_Occurrence(arr, n):\n    # Write y...        False
# 13  def sort_mixed_list(mixed_list):\n    # Your c...        False
# 14  def freq_element(lst):\n    return {}\n\n# Tes...        False
# 15  def text_match(text):\n    return 'Found a mat...        False
# 16          def compute_Last_Digit(a, b):\n    return        False
# 17  def min_length_list(list):\n    return min(lis...        False
# 18  def check_equilateral(a,b,c):\n    if a==b==c:...         True
# 19       def parallelogram_area(a,b):\n    return a*b         True
# 20           def tn_gp(n,a,r):\n    return a*r**(n-1)        False
# 21  def find_Max_Num(digits, num_digits):\n    max...        False
# 22  def opposite_Signs(a,b):\n    if a*b < 0:\n   ...         True
# 23        def is_octagonal(n):\n    return n % 6 == 0        False
# 24  def count_Substrings(string, length):\n    cou...         True
# 25  def dif_Square(n):\n    if n == 0:\n        re...        False
# 26  def is_samepatterns(patterns, sequence):\n    ...        False
# 27  def tetrahedral_number(n):\n    return 0.5 * n...        False
# 28  def volume_sphere(radius):\n    return 4/3*3.1...         True
# 29                    def get_Char(s):\n    return ""        False
# 30  def sequence(n):\n    if n == 1:\n        retu...        False
# 31    def centered_hexagonal_number(n):\n    return 0        False
# 32                    def closest_num(n):\n    return        False
# 33  def find_substring(string_list, substring):\n ...        False
# 34  def is_undulating(n):\n    # Your code here\n ...        False
# 35                def power(a, b):\n    return a ** b         True
# 36  def index_minimum(tuples):\n    # Your code he...        False
# 37  def Find_Min_Length(list):\n    min_length = 0...        False
# 38  def decimal_to_binary(decimal_number):\n    bi...         True
# 39  def next_smallest_palindrome(n):\n    # Write ...        False
# 40  def count(list):\n    count = 0\n    for i in ...         True
# 41  def odd_Equivalent(string, n):\n    # Your cod...        False
# 42  def common_in_nested_lists(nested_list):\n    ...        False
# 43  def check_integer(string):\n    try:\n        ...         True
# 44               def assign_freq(tuples):\n    return        False
# 45  def empty_dit(dit):\n    for i in dit:\n      ...         True
# 46  def search(arr, target):\n    # Write your cod...        False
# 47  def smartNumber(n):\n    return 10000000000000...        False
# 48  def amicable_numbers_sum(n):\n    sum = 0\n   ...        False
# 49  def max_occurrences(list):\n    max_count = 0\...         True
#
#    error_message  generation_time  cyclomatic_complexity  generation_idx
# 0           None        29.545906                      7               0
# 1           None       405.833809                      2               0
# 2           None         4.439466                      1               0
# 3           None         5.269413                      1               0
# 4           None         5.222691                      1               0
# 5           None         5.013457                      1               0
# 6           None         5.303037                      3               0
# 7           None         6.730649                      5               0
# 8           None         6.265986                      1               0
# 9           None        10.498238                      3               0
# 10          None        12.700543                      2               0
# 11          None         2.898887                      2               0
# 12          None        20.006904                      5               0
# 13          None         5.316081                      5               0
# 14          None        51.887021                      1               0
# 15          None         7.873149                      2               0
# 16          None         3.575568                      4               0
# 17          None         5.523380                      2               0
# 18          None         6.663072                      2               0
# 19          None         3.906085                      1               0
# 20          None         4.996740                      1               0
# 21          None        10.762749                      2               0
# 22          None         5.479847                      1               0
# 23          None         3.698838                      1               0
# 24          None        12.999875                      2               0
# 25          None        15.788678                      2               0
# 26          None         4.203531                      8               0
# 27          None        14.444637                      1               0
# 28          None         7.193995                      1               0
# 29          None         2.386570                      3               0
# 30          None        14.594222                      3               0
# 31          None         3.009004                      1               0
# 32          None         3.129438                      1               0
# 33          None         7.062751                      3               0
# 34          None         3.471647                      4               0
# 35          None         2.689248                      4               0
# 36          None         4.319297                      1               0
# 37          None        10.017262                      2               0
# 38          None        10.723990                      1               0
# 39          None         4.883696                      3               0
# 40          None         7.039236                      1               0
# 41          None        13.534411                      3               0
# 42          None         5.592565                      1               0
# 43          None         5.301022                      7               0
# 44          None         3.562628                      2               0
# 45          None         4.877567                      2               0
# 46          None         4.273575                      2               0
# 47          None       311.072221                      5               0
# 48          None        15.231571                     11               0
# 49          None        13.129504                      2               0
